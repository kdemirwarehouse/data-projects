# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load():
  data = pd.read_csv("healthcare-dataset-stroke-data.csv")
  return data

# %%
df = load()

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
plt.figure(figsize=(6,3))
plt.hist(df["bmi"], bins=30)
plt.xlabel("bmi")
plt.ylabel("frequency")
plt.title("BMI Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["bmi"].dropna())
plt.ylabel("BMI")
plt.title("BMI boxplot")
plt.show()

# %%
df["bmi"].isnull().sum()
# Out:
# np.int64(201)

# %%
plt.figure(figsize=(6,3))
sns.heatmap(df.isnull(),cbar=False)
plt.title("Missing value heatmap")
plt.show()

# %%
df["bmi"].count()
# Out:
# np.int64(4909)

# %%
len(df)
# Out:
# 5110

# %%
bmi_median = df["bmi"].median()

# %%
bmi_median
# Out:
# 28.1

# %%
df["bmi"] = df["bmi"].fillna(bmi_median)

# %%
df["bmi"].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.isnull(),cbar=False)
plt.title("Missing value heatmap")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.histplot(df["bmi"],bins=30)
plt.title("BMI Distribution after median imputation")
plt.show()

plt.figure(figsize=(6,3))
plt.boxplot(df["bmi"])
plt.title("BMI boxplot after median imputation")
plt.show()

# %%
q1 = df["bmi"].quantile(0.25)
q3 = df["bmi"].quantile(0.75)

iqr = q3 - q1

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

# %%
lower_bound, upper_bound
# Out:
# (np.float64(10.300000000000006), np.float64(46.29999999999999))

# %%
df[(df["bmi"] < lower_bound) | (df["bmi"] > upper_bound)]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 21    13861  Female  52.0             1              0          Yes
# 66    17004  Female  70.0             0              0          Yes
# 113   41069  Female  45.0             0              0          Yes
# 254   32257  Female  47.0             0              0          Yes
# 258   28674  Female  74.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 4906  72696  Female  53.0             0              0          Yes
# 4952  16245    Male  51.0             1              0          Yes
# 5009  40732  Female  50.0             0              0          Yes
# 5057  38349  Female  49.0             0              0          Yes
# 5103  22127  Female  18.0             0              0           No
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.shape
# Out:
# (5110, 12)

# %%
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

# %%
cat_cols
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
for col in cat_cols:
  print(df[col].value_counts())
  print("-" * 30)
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64
# ------------------------------
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64
# ------------------------------
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64
# ------------------------------
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64
# ------------------------------
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64
# ------------------------------

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="gender")
plt.title("gender distribution")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=df,x="ever_married")
plt.title("ever_married status")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="work_type")
plt.title("work_type distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="smoking_status")
# Out:
# <Axes: xlabel='smoking_status', ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="Residence_type")
plt.title("Residence_type countplot")
plt.show()

# %%
df = df[df["gender"] != "Other"]

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Name: count, dtype: int64

# %%
df.select_dtypes(include="object")
# Out:
#       gender ever_married      work_type Residence_type   smoking_status
# 0       Male          Yes        Private          Urban  formerly smoked
# 1     Female          Yes  Self-employed          Rural     never smoked
# 2       Male          Yes        Private          Rural     never smoked
# 3     Female          Yes        Private          Urban           smokes
# 4     Female          Yes  Self-employed          Rural     never smoked
# ...      ...          ...            ...            ...              ...
# 5105  Female          Yes        Private          Urban     never smoked
# 5106  Female          Yes  Self-employed          Urban     never smoked
# 5107  Female          Yes  Self-employed          Rural     never smoked
# 5108    Male          Yes        Private          Rural  formerly smoked
# 5109  Female          Yes       Govt_job          Urban          Unknown
#
# [5109 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["gender_label"] = label_encoder.fit_transform(df["gender"])
df
# Out:
# /tmp/ipython-input-3972373000.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender_label"] = label_encoder.fit_transform(df["gender"])
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# ...

# %%
label_encoder = LabelEncoder()
df["ever_married_label"] = label_encoder.fit_transform(df["ever_married"])
df
# Out:
# /tmp/ipython-input-3663593239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ever_married_label"] = label_encoder.fit_transform(df["ever_married"])
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# ...

# %%
label_encoder = LabelEncoder()
df["residance_type_label"] = label_encoder.fit_transform(df["Residence_type"])
# Out:
# /tmp/ipython-input-3827237737.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["residance_type_label"] = label_encoder.fit_transform(df["Residence_type"])

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df=df.drop(columns=["gender","ever_married","Residence_type"])

# %%
df

# %%
df = pd.get_dummies(
    df,
    columns=["work_type","smoking_status"],
    drop_first = True
)

# %%
df
# Out:
#          id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0      9046  67.0             0              1             228.69  36.6
# 1     51676  61.0             0              0             202.21  28.1
# 2     31112  80.0             0              1             105.92  32.5
# 3     60182  49.0             0              0             171.23  34.4
# 4      1665  79.0             1              0             174.12  24.0
# ...     ...   ...           ...            ...                ...   ...
# 5105  18234  80.0             1              0              83.75  28.1
# 5106  44873  81.0             0              0             125.20  40.0
# 5107  19723  35.0             0              0              82.99  30.6
# 5108  37544  51.0             0              0             166.29  25.6
# 5109  44679  44.0             0              0              85.28  26.2
#
#       stroke  gender_label  ever_married_label  residance_type_label  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5109 entries, 0 to 5109
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              5109 non-null   int64
#  1   age                             5109 non-null   float64
#  2   hypertension                    5109 non-null   int64
#  3   heart_disease                   5109 non-null   int64
#  4   avg_glucose_level               5109 non-null   float64
#  5   bmi                             5109 non-null   float64
#  6   stroke                          5109 non-null   int64
#  7   gender_label                    5109 non-null   int64
#  8   ever_married_label              5109 non-null   int64
#  9   residance_type_label            5109 non-null   int64
#  10  work_type_Never_worked          5109 non-null   bool
#  11  work_type_Private               5109 non-null   bool
# ...

# %%
from sklearn.preprocessing import RobustScaler
scaler_robust = RobustScaler()
df_robust = pd.DataFrame(scaler_robust.fit_transform(df), columns = df.columns)
df_robust
# Out:
#             id       age  hypertension  heart_disease  avg_glucose_level  \
# 0    -0.755386  0.611111           0.0            1.0           3.712619
# 1     0.399805  0.444444           0.0            0.0           2.994030
# 2    -0.157440  0.972222           0.0            1.0           0.381004
# 3     0.630301  0.111111           0.0            0.0           2.153324
# 4    -0.955397  0.944444           1.0            0.0           2.231750
# ...        ...       ...           ...            ...                ...
# 5104 -0.506409  0.972222           1.0            0.0          -0.220624
# 5105  0.215457  1.000000           0.0            0.0           0.904206
# 5106 -0.466060 -0.277778           0.0            0.0          -0.241248
# 5107  0.016855  0.166667           0.0            0.0           2.019267
# 5108  0.210200 -0.027778           0.0            0.0          -0.179104
#
#            bmi  stroke  gender_label  ever_married_label  \
# ...

# %%
df_robust.describe()
# Out:
#                 id          age  hypertension  heart_disease  \
# count  5109.000000  5109.000000   5109.000000    5109.000000
# mean     -0.011056    -0.049167      0.097475       0.054022
# std       0.573450     0.628155      0.296633       0.226084
# min      -0.998699    -1.247778      0.000000       0.000000
# 25%      -0.519795    -0.555556      0.000000       0.000000
# 50%       0.000000     0.000000      0.000000       0.000000
# 75%       0.480205     0.444444      0.000000       0.000000
# max       0.976018     1.027778      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke  gender_label  \
# count        5109.000000  5109.000000  5109.000000   5109.000000
# mean            0.386985     0.084811     0.048738      0.413975
# std             1.228901     0.855532     0.215340      0.492592
# min            -0.997558    -1.977778     0.000000      0.000000
# 25%            -0.397286    -0.477778     0.000000      0.000000
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Length: 5109, dtype: bool

# %%
mantiksiz = df[(df["age"] > 120) | (df["age"] < 0)]
mantiksiz if not mantiksiz.empty else "Tum yas degerleri tutarlı"
# Out:
# 'Tum yas degerleri tutarlı'

# %%
#target ile featureyi birbirinden ayırdık
X = df.drop("stroke", axis=1)
y = df["stroke"]

# %%
X.shape
#x -> feature
# Out:
# (5109, 16)

# %%
y.shape
#y -> target
# Out:
# (5109,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,y,
    test_size = 0.2,#20 % test, %80 train
    random_state = 42,
    stratify=y
)

# %%
X_train.shape
# Out:
# (4087, 16)

# %%
y_train.shape
# Out:
# (4087,)

# %%
scale_cols = ["age", "avg_glucose_level", "bmi"]

from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train[scale_cols] = scaler.fit_transform(X_train[scale_cols])

# %%
X_test[scale_cols] = scaler.transform(X_test[scale_cols])
